# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 24px;"> Question 1 </div>

# %% [markdown]
# <div style="text-align: center; font-weight: bold;"> Part 1 </div>

# %% [markdown]
# Show that any proper, SISO, linear, time-invarient, minimuim phase system with relative degree r = 1 can be exactly represented in the following form
# $$
# \dot{x} = ax + bu + c^{T}z, \;\; \dot{z} = Az + Bx
# $$
# where $x \in \mathbf{R}$ is the output and $u \in \mathbf{R}$ is the input and A is a Hurwitz matrix

# %% [markdown]
# \begin{align*}
# \text{Linear SISO System: } \dot{x} &= Ax + Bu, \;\; y = Cx \\
# \text{where } &x \in \mathbf{R}^{n} \text{ is the state } \\
# &u \in \mathbf{R} \text{ is the control input}\\
# &y \in \mathbf{R} \text{ is the measured output}\\
# \end{align*}

# %% [markdown]
# The relative degree $\textbf{r}$ is defined as the number of times the output y must be differentiated until the control input u explicitly appears in the resulting expression.

# %% [markdown]
# \begin{align*}
#
# \text{Relative degree of the transfer function: }  r &= n -m \longrightarrow n - m = 1\\
# CA^{i}B = 0, \; \text{for } i &= 0,1,\cdots, n-m -2,CA^{n-m-1}B \neq  0\\
# \text{Relative degree: } r &= 1 \text{ for  } CA^{n-m-1}B \neq 0\\
# \longrightarrow r &= 1 \text{ for  } CB \neq 0\\
# \text{Measured Output: } y &= Cx\\
# \text{First derrivative of the output: } \dot{y} &= CAx + CBu \\
# \end{align*}

# %% [markdown]
# $$
# \text{Coordinate Change}
# $$
#
# $$
# \begin{align*}
# \text{Let } \xi & \triangleq Cx\\
# z_{i} &\triangleq x_{i} \;\;\text{where}\;\;i=1,\cdots,m \\
# \dot{z} &= N z + P \, \xi, \\
# \dot{\xi} &= R z + S \, \xi + \beta u, \\
# y &= \xi
# \end{align*}
# $$

# %% [markdown]
# <div style="text-align: center; font-weight: bold;"> Part 2 </div>

# %% [markdown]
# Show that the controller
# $$
# \dot{y} = x^{2}, \;\; u = -yN(y)x
# $$
# where N(y) is a Nussbaum gain function, results in boundedness of all signals and convergence of the output x and the internal state z to zero regardless of the values of a, c, A, B, and b as long as $b \neq 0$

# %% [markdown]
# \begin{align*}
# \text{Dynamics: } \dot{x} &= ax + bu + c^{T}z \\
# \dot{z} &= Az + Bx\\
# \text{Controller: } \dot{y} &= x^{2} \\
# u &= -y N(y)x\\
# \text{Closed Loop: } \dot{\eta} &=
# \begin{bmatrix} \dot{x} \\ \dot{z} \\ \dot{y}     \end{bmatrix}  \\
# &= \begin{bmatrix} ax - byN(y)x + c^{T}z \\  Az + Bx  \\x^2    \end{bmatrix} \\
# &= f(\eta)\\
# \text{Lyapunov Function: } V(\eta) &= \frac{1}{2}x^2 + \frac{1}{2}z^{T}Pz\\
# \text{Khalil Theorem 4.5: } P = P^{T}>0&\text{ so that } A^{T}P+PA= -Q \text{ with } Q>0\\
# \text{Derrivative of Lyapunov Function: } \frac{1}{dt}V(\eta) &= x\dot{x} + z^{T}P\dot{z} \\
# &= x\left( ax - byN(y)x + c^{T}z \right) + z^{T}P\left(Az + Bx    \right)\\
# &=  ax^{2} - byN(y)x^{2} + c^{T}zx+ z^{T}PAz + xz^{T}PB\\
# &=  \left(a - byN(y)\right) \dot{y} + c^{T}zx+ z^{T}PAz + xz^{T}PB\\
# &z^{T}PAz \text{   term}\\
# z^{T}PAz &= (z^{T}PAz)^{T}\\
# (z^{T}PAz)^{T} &= z^{T}A^{T}P^{T}z\\
# &= z^{T}A^{T}Pz\\
# \longrightarrow z^{T}PAz &= \frac{1}{2}\left( z^{T}PAz +  z^{T}A^{T}Pz  \right)\\
# &= \frac{1}{2}z^{T}\left(PA + A^{T}P\right)z\\
# &= -\frac{1}{2}z^{T} Q z\\
# \frac{1}{dt}V(\eta) &= \left(a - byN(y)\right) \dot{y} + c^{T}zx-\frac{1}{2}z^{T} Q z+ xz^{T}PB
# \end{align*}

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 24px;"> Question 2 </div>

# %% [markdown]
# \begin{align*}
# \text{Dynamics: }& M(q)\ddot{q} + V_{m}(q,\dot{q})\dot{q} + F_{s}(\dot{q})+ F_{d}(\dot{q}) + F_{k}(q) = \tau \\
# \text{Angular Position (rad): }& q = [q_{1}, \; q_{2}]^{T}\\
# \text{Angular Velocities (rad): }& \dot{q} = [\dot{q}_{1}, \; \dot{q}_{2}]^{T}
# \end{align*}

# %% [markdown]
# \begin{align*}
# \text{Tracking Error: }& e = q_{d} - q\\
# \text{Filtered Tracking Error: }& r = \dot{e} + \alpha e \;\;\; \text{ where } \alpha > 0 \text{ is a design parameter} \\
# \text{Error Dynamics: }& \dot{e} = r -\alpha e\\
# & M(q)\dot{r} = Y(q,\dot{q},q_{d},\dot{q}_d,\ddot{q}_d)\theta - V_{m}(q,\dot{q})r - \tau
# \end{align*}

# %% [markdown]
# \begin{align*}
# \text{Linear regression equation: }& \tau_{f} = Y_{f}\theta\\
# \text{Prediction error: }& \varepsilon = \tau_{f} - Y_{f}\hat{\theta} = Y_{f}\tilde{\theta} \\
# \text{Design: }& \tau = Y\hat{\theta} + kr + e\;\;, \dot{\hat{\theta}}=\phi(t,r,\hat{\theta}),\;\;\;\;\; where\;\; k = k^{T} > 0\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# \text{Plugging Controller in Dynamics : } M(q)\dot{r} &= Y\theta - V_{m}r - \left[Y\hat{\theta} + kr + e    \right] \\
#  &= Y \tilde{\theta} - V_{m}r - kr - e
# \end{align*}

# %% [markdown]
# $$ \text{Closed Loop: } \dot{z} = \begin{bmatrix} \dot{r} \\ \dot{e} \\ \dot{\tilde{\theta}} \end{bmatrix} =
# \begin{bmatrix} M^{-1}\left( Y \tilde{\theta} - V_{m}r - kr - e \right) \\  r -\alpha e \\ -\phi(t,r,\hat{\theta})      \end{bmatrix} =
# f(t,z)
# $$

# %% [markdown]
# \begin{align*}
# \text{Candidate Lyapunov Function: } V(z)&= \frac{1}{2}r^{T}Mr + \frac{1}{2}e^{T}e + \frac{1}{2}\tilde{\theta}^{T}\Gamma^{-1}\tilde{\theta} \\
#
# \text{Lie Derivative: } L_{f,t}V(t,z) &=
# r^{t}Y\tilde{\theta} - r^{t}V_{m}r- r^{t}kr -r^{T}e + \frac{1}{2}r^{T}\dot{M}r +
# e^{T}r   - e^{T}\alpha e -
# \tilde{\theta}\Gamma^{-1}\phi(t,r,\hat{\theta})
#  \\
#
# &=
# r^{t}Y\tilde{\theta} + r^{t}\left(\frac{1}{2}\dot{M} -   V_{m}\right)r- r^{T}e -  r^{t}kr  +
# e^{T}r   - e^{T}\alpha e -
# \tilde{\theta}\Gamma^{-1}\phi(t,r,\hat{\theta})  \\
#
# \text{Hint 3: }  x^{T}(\frac{1}{2}\dot{M} - V_{m})x &= 0 \\
#
# &=
# r^{t}Y\tilde{\theta} - r^{t}kr  -r^{T}e +
# e^{T}r   - e^{T}\alpha e -
# \tilde{\theta}\Gamma^{-1}\phi(t,r,\hat{\theta})  \\
#
# &=
# r^{t}Y\tilde{\theta} - r^{t}kr
# - e^{T}\alpha e -
# \tilde{\theta}\Gamma^{-1}\phi(t,r,\hat{\theta})  \\
#
# \text{Hint 4: If a matrix } S\in \mathbf{R}^{n\times n} \text{ is skew symmetric, then  } x^{T}Sx &= 0 \; \forall \; x\in\mathbf{R}^{n} \\
#
# &=
# r^{t}Y\tilde{\theta} -  r^{T}kr -
# \tilde{\theta}\Gamma^{-1}\phi(t,r,\hat{\theta})  \\
# \end{align*}

# %% [markdown]
# \begin{align*}
# \text{Decision: } \dot{\hat{\theta}} &= \Gamma Y^{T}r + \Gamma Y_{f}^{T}\varepsilon \\
#
# \rightarrow L_{f,t}V(t,z) &=
# r^{t}Y\tilde{\theta} -  r^{T}kr -
# \tilde{\theta}\Gamma^{-1} \left( \Gamma Y^{T}r + \Gamma Y_{f}^{T}\varepsilon \right)\\
#
# &= -  r^{T}kr - \tilde{\theta}Y_{f}^{T}\varepsilon \\
#
# &= -  r^{T}kr - \tilde{\theta}Y_{f}^{T}Y_{f}\tilde{\theta}  \\
#
# & \longrightarrow L_{f,t}V(t,z) = -  r^{T}kr - \tilde{\theta}Y_{f}^{T}Y_{f}\tilde{\theta}  \\
# \end{align*}
